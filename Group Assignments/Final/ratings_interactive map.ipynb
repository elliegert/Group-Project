# %% [markdown]
# # Week 9 Group Assignment:
# ## Figuring out our "Common Characterstics"
#
# This notebook will explore what the predominant characterstics of our 80 locations are. To do this, we will do bar charts of each characterstic (or characterstic group) to figure out what the predominant characterstic is. Once we do this, our goal is to *score* each location based on how many of the 5 characterstics it has. For example, if it has 5/5 it will get a score of 5, 4/5 = score of 4, and so on. Finally, we will then map these locations based on their (color-coded) scores to understand if indeed the locations all share similar characterstics that could potentially make them more dangerous than other locations.
#
# To get our 80 location points, we used [data](https://geohub.lacity.org/datasets/ladot::los-angeles-collisions-2014through2019/about) from LA City Geohub that tracks Collisions in Los Angeles between 2014-2019. We filtered this data to include only locations where a fatality occured, and then filtered this down further to locations where at least 2 collisions happened at the same location. This brought us to 82 collision locations.

# %% [markdown]
# ## Step 1:
# Import Libraries

# %%
# for general data wrangling tasks
import pandas as pd

# to read and visualize spatial data
import geopandas as gpd

# to provide basemaps 
import contextily as ctx

# to give more power to your figures (plots)
import matplotlib.pyplot as plt

import plotly.express as px
# Out:
# /opt/conda/lib/python3.9/site-packages/geopandas/_compat.py:106: UserWarning: The Shapely GEOS version (3.9.1-CAPI-1.14.2) is incompatible with the GEOS version PyGEOS was compiled with (3.10.1-CAPI-1.16.0). Conversions between both will be slow.
#   warnings.warn(

# %% [markdown]
# ## Step 2:
# Import Data
# This data frame compiles all of our data from various notebooks that we have worked on throughout the quarter. To do this, we wrote our cleaned up dataframes for our various notebooks to file (both csv and geojson), and then combined them all into one notebook in one master dataframe.

# %%
# importing data
master = pd.read_csv('Data/SIMPLIFIED_speeds_streets_lights_locations_buffer_buildings.csv')

# %%
master.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 82 entries, 0 to 81
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     82 non-null     int64
#  1   Location               82 non-null     object
#  2   Longitude              82 non-null     float64
#  3   Latitude               82 non-null     float64
#  4   25 mph                 82 non-null     int64
#  5   30 mph                 82 non-null     int64
#  6   35 mph                 82 non-null     int64
#  7   40 mph                 82 non-null     int64
#  8   45 mph                 82 non-null     int64
#  9   Percent Service_S      82 non-null     float64
#  10  Percent Residential_S  82 non-null     float64
#  11  Percent Footway_S      82 non-null     float64
#  12  Percent Primary_S      82 non-null     float64
#  13  Percent Secondary_S    82 non-null     float64
#  14  Percent Tertiary_S     82 non-null     float64
#  15  time_code              82 non-null     int64
#  16  lights_count           82 non-null     int64
#  17  Percent Hospital_B     81 non-null     float64
#  18  Percent School_B       81 non-null     float64
#  19  Percent Unknown_B      81 non-null     float64
#  20  Percent Commercial_B   81 non-null     float64
#  21  Percent Industrial_B   81 non-null     float64
#  22  Percent Parking_B      81 non-null     float64
#  23  Percent Residential_B  81 non-null     float64
#  24  geometry               82 non-null     object
# dtypes: float64(15), int64(8), object(2)
# memory usage: 16.1+ KB

# %% [markdown]
# ## Step 3: Getting our **Common Characteristics**
#
# ### **Street Lights**
# Here we are going to find the mean # of street lights that fall within the 100-feet (or 300 meter) buffer zone surrounding each location. We are doing this because we are interested in finding the locations that have fewer than the mean number of streetlights per location.

# %%
# Finding the mean # of streetlights
master['lights_count'].describe()
# Out:
# count    82.000000
# mean      2.634146
# std       1.453070
# min       1.000000
# 25%       2.000000
# 50%       2.000000
# 75%       3.000000
# max       8.000000
# Name: lights_count, dtype: float64

# %% [markdown]
# #### mean number of streetlights = **2.63**
# So, this means that for streetlights, our **common characterstic** will be locations that have a streetlight count less than 2.63

# %% [markdown]
# ### **Building Types**
# Here we are going to make a bar chart of the percentages of building types to determine which building type has the highest percentage amongst our locations.

# %%
# getting sum of columns to plug into bar charts
master.sum()
# Out:
# ID                                                                12320064
# Location                 ALVARADO ST & BEVERLY BLVD, LOS ANGELES, CAAVA...
# Longitude                                                     -9706.003811
# Latitude                                                       2794.715834
# 25 mph                                                                  70
# 30 mph                                                                  91
# 35 mph                                                                 277
# 40 mph                                                                  53
# 45 mph                                                                   3
# Percent Service_S                                              2940.541834
# Percent Residential_S                                          2537.015589
# Percent Footway_S                                               786.888601
# Percent Primary_S                                               793.267404
# Percent Secondary_S                                             706.594294
# Percent Tertiary_S                                              435.692278
# time_code                                                              199
# lights_count                                                           216
# Percent Hospital_B                                               13.038916
# Percent School_B                                                 20.482999
# Percent Unknown_B                                                891.77642
# Percent Commercial_B                                            767.194962
# Percent Industrial_B                                             345.01566
# Percent Parking_B                                                26.168734
# Percent Residential_B                                           6036.32231
# geometry                 POINT (-118.2703238 34.06666183)POINT (-118.26...
# dtype: object

# %%
# %matplotlib inline
plt.style.use('ggplot')
x = ['Hospital', 'School', 'Unknown', 'Commercial', 'Industrial', 'Parking', 'Residential']
Totals = [13.04, 20.48, 891.78, 767.20, 345.02, 26.17, 6036.32]

x_pos = [i for i, _ in enumerate(x)]

plt.figure(figsize=(10, 10))
plt.bar(x_pos, Totals, color='green')
plt.xlabel("Building Types")
plt.ylabel("# of occurences")
plt.title("Building Types within 200 meters of each location")

plt.xticks(x_pos, x)

plt.show()

# %% [markdown]
# #### Predominant Building Type = **Residential**
# So, this means that for building type, our **common characterstic** will be locations where over 50% of building type is equal to **Residential**

# %% [markdown]
# ### **Street Type**
# Here we are going to make a bar chart of the percentages of street types to determine which street type has the highest percentage amongst our locations.

# %%
# %matplotlib inline
plt.style.use('ggplot')
x = ['Service', 'Residential', 'Footway', 'Primary', 'Secondary', 'Tertiary']
Totals = [2940.54, 2537.02, 786.89, 793.27, 706.59, 435.69]

x_pos = [i for i, _ in enumerate(x)]

plt.figure(figsize=(10, 10))
plt.bar(x_pos, Totals, color='blue')
plt.xlabel("Street Types")
plt.ylabel("# of occurences")
plt.title("Street Types within .25 miles (400 meters) of each location")

plt.xticks(x_pos, x)

plt.show()

# %% [markdown]
# #### Predominant Street Type = **Service**
# So, this means that for street type, our **common characterstic** will be locations where over 50% of street type is equal to **Service**

# %% [markdown]
# ### **Time Code**
# Here we are going to make a bar chart of 3 time categories that colllisions fall into, to see what the predominant time category where collisions took place. To do this, however, we will import a csv spreadsheet that has datapoints of all of the locations from our original dataset where at least 1 fatality occured, and where multiple collisions occured at the same collision. This dataset has 169 datapoints (which makes sense because from that we filtered out duplicate locations). But to understand the different times of days where these collisions happened, we will need to look at all of the collisions before we filtered out the duplicate locations.
#
# Time Codes =
# * 1 - Morning: 12:01am - 6:30am
# * 2 - Day: 6:31am - 4:45pm
# * 3 - Night: 4:46pm - 12:00am

# %%
# import new csv with 169 locations

# %%
time = pd.read_csv('Data/unfiltered_locations_time_codes.csv')

# %%
time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   X               169 non-null    float64
#  1   Y               169 non-null    float64
#  2   OBJECTID        169 non-null    int64
#  3   collision_time  169 non-null    int64
#  4   Unnamed: 4      169 non-null    object
#  5   time code       169 non-null    int64
#  6   day_of_week     169 non-null    int64
#  7   match_addr      169 non-null    object
# dtypes: float64(2), int64(4), object(2)
# memory usage: 10.7+ KB

# %%
# getting value counts of # of occurences for each time code
time['time code']. value_counts()
# Out:
# 3    93
# 2    51
# 1    25
# Name: time code, dtype: int64

# %%
# %matplotlib inline
plt.style.use('ggplot')
x = ['1 - Morning', '2 - Day', '3 - Night ']
Totals = [25, 51, 93]

x_pos = [i for i, _ in enumerate(x)]

plt.figure(figsize=(10, 10))
plt.bar(x_pos, Totals, color='purple')
plt.xlabel("Time of Collision")
plt.ylabel("# of occurences")
plt.title("Collision Times")

plt.xticks(x_pos, x)

plt.show()

# %% [markdown]
# #### Predominant time that collision took place = **Night**
# So, this means that for time code, our **common characterstic** will be locations where collisions took place at **Night**

# %% [markdown]
# ## Speed
# Here we are first going to clean up our speed data and then create a bar chart to see what speed is most common at our crash locations.

# %%
master
# Out:
#         ID                                      Location   Longitude  \
# 0   211128   ALVARADO ST & BEVERLY BLVD, LOS ANGELES, CA -118.270324
# 1   163711       AVALON BLVD & 118TH PL, LOS ANGELES, CA -118.265210
# 2    30937    BEVERLY BLVD & HUDSON AVE, LOS ANGELES, CA -118.333482
# 3   218461        CENTRAL AVE & 29TH ST, LOS ANGELES, CA -118.256083
# 4   216930        CENTRAL AVE & 91ST ST, LOS ANGELES, CA -118.256519
# ..     ...                                           ...         ...
# 77  206521        WESTERN AVE & 79TH ST, LOS ANGELES, CA -118.309022
# 78  108953        WESTERN AVE & 80TH ST, LOS ANGELES, CA -118.309024
# 79  179031  WILSHIRE BLVD & FAIRFAX AVE, LOS ANGELES, CA -118.362514
# 80  136194   WINNETKA AVE & HATTERAS ST, LOS ANGELES, CA -118.571422
# 81  154179       WOODLEY AVE & RAYEN ST, LOS ANGELES, CA -118.485111
#
#      Latitude  25 mph  30 mph  35 mph  40 mph  45 mph  Percent Service_S  ...  \
# 0   34.066662       0       0       2       0       0          36.817102  ...
# 1   33.925480       0       5       5       0       0          37.254902  ...
# 2   34.076157       3       0       3       0       0           8.695652  ...
# 3   34.016045       0       0       0       0       0          39.088729  ...
# 4   33.953896       0       1       0       0       0          34.582133  ...
# ..        ...     ...     ...     ...     ...     ...                ...  ...
# 77  33.967258       0       0       6       0       0          20.634921  ...
# 78  33.966213       0       7       7       0       0          21.052632  ...
# 79  34.063030      13      13      13       0       0          28.070175  ...
# 80  34.176991       0       0       2       0       0          20.879121  ...
# 81  34.230339       0       0       3       3       0          33.582090  ...
#
#     time_code  lights_count  Percent Hospital_B  Percent School_B  \
# 0           2             5                 0.0           0.44843
# 1           3             2                 0.0           0.00000
# 2           2             2                 0.0           0.00000
# 3           2             3                 0.0           0.00000
# 4           3             2                 0.0           0.00000
# ..        ...           ...                 ...               ...
# 77          1             2                 0.0           0.00000
# 78          3             3                 0.0           0.00000
# 79          2             2                 0.0           0.00000
# 80          3             1                 0.0           0.00000
# 81          3             1                 0.0           0.00000
#
#     Percent Unknown_B  Percent Commercial_B  Percent Industrial_B  \
# 0            4.932735             15.695067              2.242152
# 1           39.628483              2.476780              0.000000
# 2           10.101010              0.000000              1.010101
# 3            3.004292             11.587983             10.729614
# 4            6.927711              6.626506              0.903614
# ..                ...                   ...                   ...
# 77           2.185792              8.469945              0.000000
# 78           2.393617              6.914894              0.000000
# 79           1.515152             10.606061              0.000000
# 80           0.000000              0.000000              0.826446
# 81           3.773585              1.415094              0.000000
#
#     Percent Parking_B  Percent Residential_B                          geometry
# 0            0.000000              76.681614  POINT (-118.2703238 34.06666183)
# 1            0.000000              57.894737  POINT (-118.2652105 33.92547989)
# 2            0.000000              88.888889  POINT (-118.3334822 34.07615662)
# 3            0.000000              74.678112  POINT (-118.2560831 34.01604462)
# 4            0.000000              85.542169  POINT (-118.2565194 33.95389557)
# ..                ...                    ...                               ...
# 77           0.000000              89.344262  POINT (-118.3090221 33.96725845)
# 78           0.000000              90.691489   POINT (-118.309024 33.96621323)
# 79           1.010101              86.868687  POINT (-118.3625135 34.06303024)
# 80           0.000000              99.173554  POINT (-118.5714218 34.17699051)
# 81           0.000000              94.811321  POINT (-118.4851105 34.23033905)
#
# [82 rows x 25 columns]

# %%
#replace all cells with at least one street sign at the mph with a number 1 to simplify
master['25 mph'].values[master['25 mph'].values >= 1] = 1
master['30 mph'].values[master['30 mph'].values >= 1] = 1
master['35 mph'].values[master['35 mph'].values >= 1] = 1
master['40 mph'].values[master['40 mph'].values >= 1] = 1
master['45 mph'].values[master['45 mph'].values >= 1] = 1

# %%
master
# Out:
#         ID                                      Location   Longitude  \
# 0   211128   ALVARADO ST & BEVERLY BLVD, LOS ANGELES, CA -118.270324
# 1   163711       AVALON BLVD & 118TH PL, LOS ANGELES, CA -118.265210
# 2    30937    BEVERLY BLVD & HUDSON AVE, LOS ANGELES, CA -118.333482
# 3   218461        CENTRAL AVE & 29TH ST, LOS ANGELES, CA -118.256083
# 4   216930        CENTRAL AVE & 91ST ST, LOS ANGELES, CA -118.256519
# ..     ...                                           ...         ...
# 77  206521        WESTERN AVE & 79TH ST, LOS ANGELES, CA -118.309022
# 78  108953        WESTERN AVE & 80TH ST, LOS ANGELES, CA -118.309024
# 79  179031  WILSHIRE BLVD & FAIRFAX AVE, LOS ANGELES, CA -118.362514
# 80  136194   WINNETKA AVE & HATTERAS ST, LOS ANGELES, CA -118.571422
# 81  154179       WOODLEY AVE & RAYEN ST, LOS ANGELES, CA -118.485111
#
#      Latitude  25 mph  30 mph  35 mph  40 mph  45 mph  Percent Service_S  ...  \
# 0   34.066662       0       0       1       0       0          36.817102  ...
# 1   33.925480       0       1       1       0       0          37.254902  ...
# 2   34.076157       1       0       1       0       0           8.695652  ...
# 3   34.016045       0       0       0       0       0          39.088729  ...
# 4   33.953896       0       1       0       0       0          34.582133  ...
# ..        ...     ...     ...     ...     ...     ...                ...  ...
# 77  33.967258       0       0       1       0       0          20.634921  ...
# 78  33.966213       0       1       1       0       0          21.052632  ...
# 79  34.063030       1       1       1       0       0          28.070175  ...
# 80  34.176991       0       0       1       0       0          20.879121  ...
# 81  34.230339       0       0       1       1       0          33.582090  ...
#
#     time_code  lights_count  Percent Hospital_B  Percent School_B  \
# 0           2             5                 0.0           0.44843
# 1           3             2                 0.0           0.00000
# 2           2             2                 0.0           0.00000
# 3           2             3                 0.0           0.00000
# 4           3             2                 0.0           0.00000
# ..        ...           ...                 ...               ...
# 77          1             2                 0.0           0.00000
# 78          3             3                 0.0           0.00000
# 79          2             2                 0.0           0.00000
# 80          3             1                 0.0           0.00000
# 81          3             1                 0.0           0.00000
#
#     Percent Unknown_B  Percent Commercial_B  Percent Industrial_B  \
# 0            4.932735             15.695067              2.242152
# 1           39.628483              2.476780              0.000000
# 2           10.101010              0.000000              1.010101
# 3            3.004292             11.587983             10.729614
# 4            6.927711              6.626506              0.903614
# ..                ...                   ...                   ...
# 77           2.185792              8.469945              0.000000
# 78           2.393617              6.914894              0.000000
# 79           1.515152             10.606061              0.000000
# 80           0.000000              0.000000              0.826446
# 81           3.773585              1.415094              0.000000
#
#     Percent Parking_B  Percent Residential_B                          geometry
# 0            0.000000              76.681614  POINT (-118.2703238 34.06666183)
# 1            0.000000              57.894737  POINT (-118.2652105 33.92547989)
# 2            0.000000              88.888889  POINT (-118.3334822 34.07615662)
# 3            0.000000              74.678112  POINT (-118.2560831 34.01604462)
# 4            0.000000              85.542169  POINT (-118.2565194 33.95389557)
# ..                ...                    ...                               ...
# 77           0.000000              89.344262  POINT (-118.3090221 33.96725845)
# 78           0.000000              90.691489   POINT (-118.309024 33.96621323)
# 79           1.010101              86.868687  POINT (-118.3625135 34.06303024)
# 80           0.000000              99.173554  POINT (-118.5714218 34.17699051)
# 81           0.000000              94.811321  POINT (-118.4851105 34.23033905)
#
# [82 rows x 25 columns]

# %%
master.sum()
# Out:
# ID                                                                12320064
# Location                 ALVARADO ST & BEVERLY BLVD, LOS ANGELES, CAAVA...
# Longitude                                                     -9706.003811
# Latitude                                                       2794.715834
# 25 mph                                                                  13
# 30 mph                                                                  19
# 35 mph                                                                  65
# 40 mph                                                                  14
# 45 mph                                                                   2
# Percent Service_S                                              2940.541834
# Percent Residential_S                                          2537.015589
# Percent Footway_S                                               786.888601
# Percent Primary_S                                               793.267404
# Percent Secondary_S                                             706.594294
# Percent Tertiary_S                                              435.692278
# time_code                                                              199
# lights_count                                                           216
# Percent Hospital_B                                               13.038916
# Percent School_B                                                 20.482999
# Percent Unknown_B                                                891.77642
# Percent Commercial_B                                            767.194962
# Percent Industrial_B                                             345.01566
# Percent Parking_B                                                26.168734
# Percent Residential_B                                           6036.32231
# geometry                 POINT (-118.2703238 34.06666183)POINT (-118.26...
# dtype: object

# %%
# %matplotlib inline
plt.style.use('ggplot')
x = ['25 mph', '30mph', '35mph', '40mph', '45mph']
Totals = [13, 19, 65, 14, 2]

x_pos = [i for i, _ in enumerate(x)]

plt.figure(figsize=(10, 10))
plt.bar(x_pos, Totals, color='red')
plt.xlabel("MPH")
plt.ylabel("# of occurences")
plt.title("Speed")

plt.xticks(x_pos, x)

plt.show()

# %% [markdown]
# From this we see that 35mph makes of the majority of the roads at the crash locations.

# %% [markdown]
# ### Step 4:
# Make a dictionary of our common characterstics and turn into dataframe

# %%
d = {'Mean # of Street Lights': [2.36], 'Predom Building Type': ['Residential'], 'Predom Street Type': ['Service'], 'Predom Collision Time': ['Night'], 'Predom Speed': ['35 mph']}
print(d)
# Out:
# {'Mean # of Street Lights': [2.36], 'Predom Building Type': ['Residential'], 'Predom Street Type': ['Service'], 'Predom Collision Time': ['Night'], 'Predom Speed': ['35 mph']}

# %%
df = pd.DataFrame(data=d)
df
# Out:
#    Mean # of Street Lights Predom Building Type Predom Street Type  \
# 0                     2.36          Residential            Service
#
#   Predom Collision Time Predom Speed
# 0                 Night       35 mph

# %% [markdown]
# ## Next Steps
# The next steps would be to see look at each location to see how many of each of the locations has all or most of the characteristics. For example, maybe we will create a score column, and then create a map of showing many have 5/5, 4/5 , ⅗. ⅖, ⅕.

# %% [markdown]
# **Visualizations of relationships between characterstics**
# We also started to explore how we could use seaborn to visualize realtionships betweeen two or more characteristics.

# %%
#import seaborn 
import seaborn as sns

# %%
sns.jointplot(data=master, x="lights_count", y="Percent Commercial_B", marginal_ticks=True)

# %%
sns.jointplot(data=master, x="lights_count", y="time_code", marginal_ticks=True)

# %% [markdown]
# ## Assigning ratings to locations based on characteristics

# %%
#copy master 
master_ratings = master.copy()

# %%
master_ratings
# Out:
#         ID                                      Location   Longitude  \
# 0   211128   ALVARADO ST & BEVERLY BLVD, LOS ANGELES, CA -118.270324
# 1   163711       AVALON BLVD & 118TH PL, LOS ANGELES, CA -118.265210
# 2    30937    BEVERLY BLVD & HUDSON AVE, LOS ANGELES, CA -118.333482
# 3   218461        CENTRAL AVE & 29TH ST, LOS ANGELES, CA -118.256083
# 4   216930        CENTRAL AVE & 91ST ST, LOS ANGELES, CA -118.256519
# ..     ...                                           ...         ...
# 77  206521        WESTERN AVE & 79TH ST, LOS ANGELES, CA -118.309022
# 78  108953        WESTERN AVE & 80TH ST, LOS ANGELES, CA -118.309024
# 79  179031  WILSHIRE BLVD & FAIRFAX AVE, LOS ANGELES, CA -118.362514
# 80  136194   WINNETKA AVE & HATTERAS ST, LOS ANGELES, CA -118.571422
# 81  154179       WOODLEY AVE & RAYEN ST, LOS ANGELES, CA -118.485111
#
#      Latitude  25 mph  30 mph  35 mph  40 mph  45 mph  Percent Service_S  ...  \
# 0   34.066662       0       0       1       0       0          36.817102  ...
# 1   33.925480       0       1       1       0       0          37.254902  ...
# 2   34.076157       1       0       1       0       0           8.695652  ...
# 3   34.016045       0       0       0       0       0          39.088729  ...
# 4   33.953896       0       1       0       0       0          34.582133  ...
# ..        ...     ...     ...     ...     ...     ...                ...  ...
# 77  33.967258       0       0       1       0       0          20.634921  ...
# 78  33.966213       0       1       1       0       0          21.052632  ...
# 79  34.063030       1       1       1       0       0          28.070175  ...
# 80  34.176991       0       0       1       0       0          20.879121  ...
# 81  34.230339       0       0       1       1       0          33.582090  ...
#
#     time_code  lights_count  Percent Hospital_B  Percent School_B  \
# 0           2             5                 0.0           0.44843
# 1           3             2                 0.0           0.00000
# 2           2             2                 0.0           0.00000
# 3           2             3                 0.0           0.00000
# 4           3             2                 0.0           0.00000
# ..        ...           ...                 ...               ...
# 77          1             2                 0.0           0.00000
# 78          3             3                 0.0           0.00000
# 79          2             2                 0.0           0.00000
# 80          3             1                 0.0           0.00000
# 81          3             1                 0.0           0.00000
#
#     Percent Unknown_B  Percent Commercial_B  Percent Industrial_B  \
# 0            4.932735             15.695067              2.242152
# 1           39.628483              2.476780              0.000000
# 2           10.101010              0.000000              1.010101
# 3            3.004292             11.587983             10.729614
# 4            6.927711              6.626506              0.903614
# ..                ...                   ...                   ...
# 77           2.185792              8.469945              0.000000
# 78           2.393617              6.914894              0.000000
# 79           1.515152             10.606061              0.000000
# 80           0.000000              0.000000              0.826446
# 81           3.773585              1.415094              0.000000
#
#     Percent Parking_B  Percent Residential_B                          geometry
# 0            0.000000              76.681614  POINT (-118.2703238 34.06666183)
# 1            0.000000              57.894737  POINT (-118.2652105 33.92547989)
# 2            0.000000              88.888889  POINT (-118.3334822 34.07615662)
# 3            0.000000              74.678112  POINT (-118.2560831 34.01604462)
# 4            0.000000              85.542169  POINT (-118.2565194 33.95389557)
# ..                ...                    ...                               ...
# 77           0.000000              89.344262  POINT (-118.3090221 33.96725845)
# 78           0.000000              90.691489   POINT (-118.309024 33.96621323)
# 79           1.010101              86.868687  POINT (-118.3625135 34.06303024)
# 80           0.000000              99.173554  POINT (-118.5714218 34.17699051)
# 81           0.000000              94.811321  POINT (-118.4851105 34.23033905)
#
# [82 rows x 25 columns]

# %% [markdown]
# **Remove extra columns**

# %%
columns_to_keep = ['ID','Location','Longitude','Latitude','geometry','35 mph', 'Percent Service_S','Percent Residential_B', 'time_code','lights_count']

# %%
master_ratings = master_ratings[columns_to_keep]

# %%
pd.set_option("display.max_rows", None, "display.max_columns", None)
master_ratings
# Out:
#         ID                                           Location   Longitude  \
# 0   211128        ALVARADO ST & BEVERLY BLVD, LOS ANGELES, CA -118.270324
# 1   163711            AVALON BLVD & 118TH PL, LOS ANGELES, CA -118.265210
# 2    30937         BEVERLY BLVD & HUDSON AVE, LOS ANGELES, CA -118.333482
# 3   218461             CENTRAL AVE & 29TH ST, LOS ANGELES, CA -118.256083
# 4   216930             CENTRAL AVE & 91ST ST, LOS ANGELES, CA -118.256519
# 5   205044             CENTRAL AVE & 92ND ST, LOS ANGELES, CA -118.256532
# 6   210379          CENTURY BLVD & HOOVER ST, LOS ANGELES, CA -118.286620
# 7   184324            CENTURY BLVD & MAIN ST, LOS ANGELES, CA -118.274077
# 8   221122      CENTURY BLVD & ST ANDREWS PL, LOS ANGELES, CA -118.311170
# 44   72094        PARTHENIA ST & HASKELL AVE, LOS ANGELES, CA -118.476392
# 45  121923          PLUMMER ST & HASKELL AVE, LOS ANGELES, CA -118.476282
# 46  210410           POLK ST & GLENOAKS BLVD, LOS ANGELES, CA -118.450074
# 47   97673         ROSCOE BLVD & HASKELL AVE, LOS ANGELES, CA -118.476700
# 48   72067         ROSCOE BLVD & LINDLEY AVE, LOS ANGELES, CA -118.527362
# 49  217687        ROSCOE BLVD & PENFIELD AVE, LOS ANGELES, CA -118.568496
# 50  187456          ROSCOE BLVD & WILLIS AVE, LOS ANGELES, CA -118.455355
# 51  137988    SAN FERNANDO RD & TRUESDALE ST, LOS ANGELES, CA -118.398205
# 52  170646  SAN FERNANDO RD SOUTHWEST RDWY & SIERRA HWY, L... -118.506133
# 53   98193  SANTA MONICA BLVD & LAS PALMAS AVE, LOS ANGELE... -118.336744
# 54   97881          SATICOY ST & DE SOTO AVE, LOS ANGELES, CA -118.588492
# 55   55551            SEASIDE AVE & NAVY WAY, LOS ANGELES, CA -118.251812
# 56  196265     SEPULVEDA BLVD & PARTHENIA ST, LOS ANGELES, CA -118.467662
# 57  184240       SEPULVEDA BLVD & VANOWEN ST, LOS ANGELES, CA -118.466162
# 58  112215  SHERMAN WAY & COLDWATER CANYON AVE, LOS ANGELE... -118.415796
# 59  185828        SHERMAN WAY & ETIWANDA AVE, LOS ANGELES, CA -118.531564
# 60  213515          SHERMAN WAY & IRVINE AVE, LOS ANGELES, CA -118.385592
# 61   95186         SHERMAN WAY & WOODMAN AVE, LOS ANGELES, CA -118.431272
# 62  212505         SLAUSON AVE & FIGUEROA ST, LOS ANGELES, CA -118.282455
# 63  135576          SUNLAND BLVD & NOHLES DR, LOS ANGELES, CA -118.336335
# 64  154627         SUNSET BLVD & FORMOSA AVE, LOS ANGELES, CA -118.346980
# 65  167936         SUNSET BLVD & MALTMAN AVE, LOS ANGELES, CA -118.277098
# 66  168756         SUNSET BLVD & MAPLETON DR, LOS ANGELES, CA -118.431923
# 67   92181    VAN NUYS BLVD & CANTERBURY AVE, LOS ANGELES, CA -118.445139
# 68  173009         VANOWEN ST & BELLAIRE AVE, LOS ANGELES, CA -118.409908
# 69  184135          VANOWEN ST & VANTAGE AVE, LOS ANGELES, CA -118.397622
# 70  142011      VENICE BLVD & ROBERTSON BLVD, LOS ANGELES, CA -118.390382
# 71  220910             VERMONT AVE & 65TH ST, LOS ANGELES, CA -118.291800
# 72  155925           VERNON AVE & CROCKER ST, LOS ANGELES, CA -118.268732
# 73  212959         VINELAND AVE & VANOWEN ST, LOS ANGELES, CA -118.370332
# 74   54862      VISTA DEL MAR & IMPERIAL HWY, LOS ANGELES, CA -118.436607
# 75  112393  WASHINGTON BLVD & BURLINGTON AVE, LOS ANGELES, CA -118.283285
# 76  180452             WESTERN AVE & 78TH ST, LOS ANGELES, CA -118.309022
# 77  206521             WESTERN AVE & 79TH ST, LOS ANGELES, CA -118.309022
# 78  108953             WESTERN AVE & 80TH ST, LOS ANGELES, CA -118.309024
# 12              90.551181          3             4
# 13              94.756554          3             4
# 14              74.168798          3             4
# 15              95.750708          2             3
# 16              84.705882          3             1
# 17              90.594059          1             5
# 18              90.144928          2             3
# 19              84.482759          2             3
# 20              83.082707          2             2
# 21              90.869565          3             1
# 22              96.819788          3             1
# 23              19.117647          3             1
# 24              57.668712          2             2
# 25              38.888889          3             1
# 26              68.478261          1             2
# 27              95.397490          3             1
# 28              89.436620          3             2
# 29              67.796610          3             2
# 30              95.000000          3             1
# 31                    NaN          2             2
# 32              82.995951          2             3
# 33              92.452830          3             3
# 34              94.273128          2             4
# 35              84.000000          1             3
# 36              70.192308          3             3
# 37              45.977011          3             3
# 38              70.129870          3             1
# 39              79.365079          3             2
# 40              83.895131          1             1
# 41              89.033943          3             2
# 42              97.297297          3             2
# 43              97.058824          2             2
# 44              84.868421          1             4
# 45              93.893130          3             4
# 46              94.163424          3             2
# 47              52.205882          1             2
# 48             100.000000          2             6
# 49              80.379747          3             2
# 50              79.746835          3             6
# 51              14.285714          3             1
# 52               0.000000          3             2
# 53               1.149425          1             4
# 54              92.771084          2             4
# 55               0.000000          3             1
# 56              32.142857          1             5
# 57              70.000000          1             4
# 58              72.727273          2             3
# 59              63.461538          2             3
# 60              77.678571          3             2
# 61              77.622378          3             5
# 62              86.639676          2             4
# 63              88.888889          3             1
# 64              73.684211          3             3
# 65              81.985294          3             3
# 66             100.000000          3             1
# 67              91.428571          3             2
# 68              97.482014          2             1
# 69              81.967213          1             3
# 70              11.538462          3             4
# 71              89.497717          3             2
# 72              93.793103          2             2
# 73              77.083333          2             8
# 74               0.000000          3             1
# 75              69.798658          3             2
# 76              87.434555          3             3
# 77              89.344262          1             2
# 78              90.691489          3             3
# 79              86.868687          2             2
# 80              99.173554          3             1
# 81              94.811321          3             1

# %%
#replace all service roads below 50% with a zero
master_ratings['Percent Service_S'].values[master_ratings['Percent Service_S'].values < 50] = 0

# %%
master_ratings.sample(10)
# Out:
#         ID                                          Location   Longitude  \
# 13  175909        CULVER BLVD & SLAUSON AVE, LOS ANGELES, CA -118.414779
# 39  125922  PACIFIC COAST HWY & FIGUEROA PL, LOS ANGELES, CA -118.284075
# 10   33367    CHAUTAUQUA BLVD & ALMOLOYA DR, LOS ANGELES, CA -118.519452
# 66  168756        SUNSET BLVD & MAPLETON DR, LOS ANGELES, CA -118.431923
# 68  173009        VANOWEN ST & BELLAIRE AVE, LOS ANGELES, CA -118.409908
# 64  154627        SUNSET BLVD & FORMOSA AVE, LOS ANGELES, CA -118.346980
# 77  206521            WESTERN AVE & 79TH ST, LOS ANGELES, CA -118.309022
# 73  212959        VINELAND AVE & VANOWEN ST, LOS ANGELES, CA -118.370332
# 54   97881         SATICOY ST & DE SOTO AVE, LOS ANGELES, CA -118.588492
# 15   58061            FIGUEROA ST & 54TH ST, LOS ANGELES, CA -118.282714
#
#      Latitude                          geometry  35 mph  Percent Service_S  \
# 13  33.998554  POINT (-118.4147788 33.99855423)       0           0.000000
# 39  33.790806  POINT (-118.2840753 33.79080582)       1           0.000000
# 10  34.035568  POINT (-118.5194522 34.03556824)       0           0.000000
# 66  34.082340  POINT (-118.4319232 34.08234024)       1           0.000000
# 68  34.193954  POINT (-118.4099077 34.19395447)       1           0.000000
# 64  34.097980   POINT (-118.3469799 34.0979805)       1           0.000000
# 77  33.967258  POINT (-118.3090221 33.96725845)       1           0.000000
# 73  34.193935  POINT (-118.3703321 34.19393539)       1          53.521127
# 54  34.208294  POINT (-118.5884923 34.20829391)       1           0.000000
# 15  33.992905  POINT (-118.2827137 33.99290466)       1           0.000000
#
#     Percent Residential_B  time_code  lights_count
# 13              94.756554          3             4
# 39              79.365079          3             2
# 10              96.610169          2             1
# 66             100.000000          3             1
# 68              97.482014          2             1
# 64              73.684211          3             3
# 77              89.344262          1             2
# 73              77.083333          2             8
# 54              92.771084          2             4
# 15              95.750708          2             3

# %%
#replace all service roads at 50% or more with a 1 for our rating system
master_ratings['Percent Service_S'].values[master_ratings['Percent Service_S'].values >= 50] = 1

# %%
master_ratings.sample(10)
# Out:
#         ID                                           Location   Longitude  \
# 34  212489           NORDHOFF ST & NOBLE AVE, LOS ANGELES, CA -118.461052
# 22  195502     GLENOAKS BLVD & WHEATLAND AVE, LOS ANGELES, CA -118.360936
# 1   163711            AVALON BLVD & 118TH PL, LOS ANGELES, CA -118.265210
# 75  112393  WASHINGTON BLVD & BURLINGTON AVE, LOS ANGELES, CA -118.283285
# 44   72094        PARTHENIA ST & HASKELL AVE, LOS ANGELES, CA -118.476392
# 24   84835        IMPERIAL HWY & CENTRAL AVE, LOS ANGELES, CA -118.255274
# 29  166529            LA BREA AVE & RODEO RD, LOS ANGELES, CA -118.355626
# 63  135576          SUNLAND BLVD & NOHLES DR, LOS ANGELES, CA -118.336335
# 59  185828        SHERMAN WAY & ETIWANDA AVE, LOS ANGELES, CA -118.531564
# 50  187456          ROSCOE BLVD & WILLIS AVE, LOS ANGELES, CA -118.455355
#
#      Latitude                          geometry  35 mph  Percent Service_S  \
# 34  34.235474  POINT (-118.4610523 34.23547363)       1                0.0
# 22  34.224087  POINT (-118.3609362 34.22408676)       0                0.0
# 1   33.925480  POINT (-118.2652105 33.92547989)       1                0.0
# 75  34.039452   POINT (-118.2832846 34.0394516)       1                0.0
# 44  34.228325  POINT (-118.4763922 34.22832489)       1                0.0
# 24  33.929466  POINT (-118.2552735 33.92946625)       1                0.0
# 29  34.020206  POINT (-118.3556258 34.02020645)       1                1.0
# 63  34.260048  POINT (-118.3363348 34.26004791)       0                0.0
# 59  34.201187  POINT (-118.5315635 34.20118713)       1                0.0
# 50  34.221466   POINT (-118.455355 34.22146606)       1                0.0
#
#     Percent Residential_B  time_code  lights_count
# 34              94.273128          2             4
# 22              96.819788          3             1
# 1               57.894737          3             2
# 75              69.798658          3             2
# 44              84.868421          1             4
# 24              57.668712          2             2
# 29              67.796610          3             2
# 63              88.888889          3             1
# 59              63.461538          2             3
# 50              79.746835          3             6

# %%
## master_ratings

# %%
#replace all service roads below 50% with a zero
master_ratings['Percent Residential_B'].values[master_ratings['Percent Residential_B'].values < 50] = 0

# %%
#replace all service roads at 50% or more with a 1 for our rating system
master_ratings['Percent Residential_B'].values[master_ratings['Percent Residential_B'].values >= 50] = 1

# %%
master_ratings
# Out:
#         ID                                           Location   Longitude  \
# 0   211128        ALVARADO ST & BEVERLY BLVD, LOS ANGELES, CA -118.270324
# 1   163711            AVALON BLVD & 118TH PL, LOS ANGELES, CA -118.265210
# 2    30937         BEVERLY BLVD & HUDSON AVE, LOS ANGELES, CA -118.333482
# 3   218461             CENTRAL AVE & 29TH ST, LOS ANGELES, CA -118.256083
# 4   216930             CENTRAL AVE & 91ST ST, LOS ANGELES, CA -118.256519
# 5   205044             CENTRAL AVE & 92ND ST, LOS ANGELES, CA -118.256532
# 6   210379          CENTURY BLVD & HOOVER ST, LOS ANGELES, CA -118.286620
# 7   184324            CENTURY BLVD & MAIN ST, LOS ANGELES, CA -118.274077
# 8   221122      CENTURY BLVD & ST ANDREWS PL, LOS ANGELES, CA -118.311170
# 9   188248    CESAR E CHAVEZ AVE & VIGNES ST, LOS ANGELES, CA -118.231832
# 10   33367     CHAUTAUQUA BLVD & ALMOLOYA DR, LOS ANGELES, CA -118.519452
# 11  138406           CRENSHAW BLVD & 63RD ST, LOS ANGELES, CA -118.330955
# 12  173875   CRENSHAW BLVD & WASHINGTON BLVD, LOS ANGELES, CA -118.331083
# 13  175909         CULVER BLVD & SLAUSON AVE, LOS ANGELES, CA -118.414779
# 14  168757            FIGUEROA ST & 108TH ST, LOS ANGELES, CA -118.282622
# 15   58061             FIGUEROA ST & 54TH ST, LOS ANGELES, CA -118.282714
# 16   84065        FIGUEROA ST & PASADENA AVE, LOS ANGELES, CA -118.211342
# 17   14631        FLORENCE AVE & CIMARRON ST, LOS ANGELES, CA -118.315563
# 18  192125        FLORENCE AVE & GRAMERCY PL, LOS ANGELES, CA -118.313738
# 19  143855          FLORENCE AVE & HOOVER ST, LOS ANGELES, CA -118.286905
# 20  185896        FOOTHILL BLVD & VALMONT ST, LOS ANGELES, CA -118.294611
# 21  148431             FULTON AVE & ERWIN ST, LOS ANGELES, CA -118.422526
# 22  195502     GLENOAKS BLVD & WHEATLAND AVE, LOS ANGELES, CA -118.360936
# 23  166954     HAYVENHURST AVE & SHERMAN WAY, LOS ANGELES, CA -118.492420
# 24   84835        IMPERIAL HWY & CENTRAL AVE, LOS ANGELES, CA -118.255274
# 25   84467        IMPERIAL HWY & SUCCESS AVE, LOS ANGELES, CA -118.249615
# 26  184104        IMPERIAL HWY & VERMONT AVE, LOS ANGELES, CA -118.291552
# 27  165861      JEFFERSON BLVD & COCHRAN AVE, LOS ANGELES, CA -118.362546
# 28   85193       LA BREA AVE & DOCKWEILER ST, LOS ANGELES, CA -118.344244
# 29  166529            LA BREA AVE & RODEO RD, LOS ANGELES, CA -118.355626
# 30    3363     LA TUNA CANYON RD & ELBEN AVE, LOS ANGELES, CA -118.331053
# 31  198214  LA TUNA CANYON RD & RT 210 E/B OFF, LOS ANGELE... -118.291577
# 32  218215    LANKERSHIM BLVD & KITTRIDGE ST, LOS ANGELES, CA -118.387802
# 33  201062  MARTIN LUTHER KING JR BLVD & HALLDALE AVE, LOS... -118.302695
# 34  212489           NORDHOFF ST & NOBLE AVE, LOS ANGELES, CA -118.461052
# 35  140850          NORDHOFF ST & TOBIAS AVE, LOS ANGELES, CA -118.451636
# 36  220670          NORMANDIE AVE & 255TH ST, LOS ANGELES, CA -118.297502
# 37   22496           OLYMPIC BLVD & ORME AVE, LOS ANGELES, CA -118.217778
# 38  149918           OSBORNE ST & OSBORNE PL, LOS ANGELES, CA -118.403236
# 39  125922   PACIFIC COAST HWY & FIGUEROA PL, LOS ANGELES, CA -118.284075
# 40  206156     PACIFIC COAST HWY & FRIES AVE, LOS ANGELES, CA -118.265339
# 41  210079      PACIFIC COAST HWY & GULF AVE, LOS ANGELES, CA -118.273985
# 42  210192  PACIFIC COAST HWY & TEMESCAL CANYON RD, LOS AN... -118.535805
# 43   19398         PARTHENIA ST & ENCINO AVE, LOS ANGELES, CA -118.515114
# 44   72094        PARTHENIA ST & HASKELL AVE, LOS ANGELES, CA -118.476392
# 45  121923          PLUMMER ST & HASKELL AVE, LOS ANGELES, CA -118.476282
# 46  210410           POLK ST & GLENOAKS BLVD, LOS ANGELES, CA -118.450074
# 47   97673         ROSCOE BLVD & HASKELL AVE, LOS ANGELES, CA -118.476700
# 48   72067         ROSCOE BLVD & LINDLEY AVE, LOS ANGELES, CA -118.527362
# 49  217687        ROSCOE BLVD & PENFIELD AVE, LOS ANGELES, CA -118.568496
# 50  187456          ROSCOE BLVD & WILLIS AVE, LOS ANGELES, CA -118.455355
# 51  137988    SAN FERNANDO RD & TRUESDALE ST, LOS ANGELES, CA -118.398205
# 52  170646  SAN FERNANDO RD SOUTHWEST RDWY & SIERRA HWY, L... -118.506133
# 53   98193  SANTA MONICA BLVD & LAS PALMAS AVE, LOS ANGELE... -118.336744
# 54   97881          SATICOY ST & DE SOTO AVE, LOS ANGELES, CA -118.588492
# 55   55551            SEASIDE AVE & NAVY WAY, LOS ANGELES, CA -118.251812
# 56  196265     SEPULVEDA BLVD & PARTHENIA ST, LOS ANGELES, CA -118.467662
# 57  184240       SEPULVEDA BLVD & VANOWEN ST, LOS ANGELES, CA -118.466162
# 58  112215  SHERMAN WAY & COLDWATER CANYON AVE, LOS ANGELE... -118.415796
# 59  185828        SHERMAN WAY & ETIWANDA AVE, LOS ANGELES, CA -118.531564
# 60  213515          SHERMAN WAY & IRVINE AVE, LOS ANGELES, CA -118.385592
# 61   95186         SHERMAN WAY & WOODMAN AVE, LOS ANGELES, CA -118.431272
# 62  212505         SLAUSON AVE & FIGUEROA ST, LOS ANGELES, CA -118.282455
# 63  135576          SUNLAND BLVD & NOHLES DR, LOS ANGELES, CA -118.336335
# 64  154627         SUNSET BLVD & FORMOSA AVE, LOS ANGELES, CA -118.346980
# 65  167936         SUNSET BLVD & MALTMAN AVE, LOS ANGELES, CA -118.277098
# 66  168756         SUNSET BLVD & MAPLETON DR, LOS ANGELES, CA -118.431923
# 67   92181    VAN NUYS BLVD & CANTERBURY AVE, LOS ANGELES, CA -118.445139
# 75  34.039452   POINT (-118.2832846 34.0394516)       1                0.0
# 76  33.969067  POINT (-118.3090221 33.96906662)       1                0.0
# 77  33.967258  POINT (-118.3090221 33.96725845)       1                0.0
# 78  33.966213   POINT (-118.309024 33.96621323)       1                0.0
# 79  34.063030  POINT (-118.3625135 34.06303024)       1                0.0
# 80  34.176991  POINT (-118.5714218 34.17699051)       1                0.0
# 81  34.230339  POINT (-118.4851105 34.23033905)       1                0.0
#
#     Percent Residential_B  time_code  lights_count
# 0                     1.0          2             5
# 1                     1.0          3             2
# 2                     1.0          2             2
# 3                     1.0          2             3
# 4                     1.0          3             2
# 5                     1.0          3             2
# 6                     1.0          3             3
# 7                     1.0          1             4
# 8                     0.0          3             2
# 9                     0.0          2             6
# 10                    1.0          2             1
# 11                    1.0          3             1
# 12                    1.0          3             4
# 13                    1.0          3             4
# 14                    1.0          3             4
# 15                    1.0          2             3
# 16                    1.0          3             1
# 17                    1.0          1             5
# 18                    1.0          2             3
# 19                    1.0          2             3
# 20                    1.0          2             2
# 21                    1.0          3             1
# 22                    1.0          3             1
# 23                    0.0          3             1
# 24                    1.0          2             2
# 25                    0.0          3             1
# 26                    1.0          1             2
# 27                    1.0          3             1
# 28                    1.0          3             2
# 29                    1.0          3             2
# 30                    1.0          3             1
# 31                    NaN          2             2
# 32                    1.0          2             3
# 33                    1.0          3             3
# 34                    1.0          2             4
# 35                    1.0          1             3
# 36                    1.0          3             3
# 37                    0.0          3             3
# 38                    1.0          3             1
# 39                    1.0          3             2
# 40                    1.0          1             1
# 41                    1.0          3             2
# 42                    1.0          3             2
# 43                    1.0          2             2
# 44                    1.0          1             4
# 45                    1.0          3             4
# 46                    1.0          3             2
# 47                    1.0          1             2
# 48                    1.0          2             6
# 49                    1.0          3             2
# 50                    1.0          3             6
# 51                    0.0          3             1
# 52                    0.0          3             2
# 53                    0.0          1             4
# 54                    1.0          2             4
# 55                    0.0          3             1
# 56                    0.0          1             5
# 57                    1.0          1             4
# 58                    1.0          2             3
# 59                    1.0          2             3
# 60                    1.0          3             2
# 61                    1.0          3             5
# 62                    1.0          2             4
# 63                    1.0          3             1
# 64                    1.0          3             3
# 65                    1.0          3             3
# 66                    1.0          3             1
# 67                    1.0          3             2
# 68                    1.0          2             1
# 69                    1.0          1             3
# 70                    0.0          3             4
# 71                    1.0          3             2
# 72                    1.0          2             2
# 73                    1.0          2             8
# 74                    0.0          3             1
# 75                    1.0          3             2
# 76                    1.0          3             3
# 77                    1.0          1             2
# 78                    1.0          3             3
# 79                    1.0          2             2
# 80                    1.0          3             1
# 81                    1.0          3             1

# %%
#replace all service roads at 50% or more with a 1 for our rating system
master_ratings['time_code'].values[master_ratings['time_code'].values < 3] = 0

# %%
#replace all service roads at 50% or more with a 1 for our rating system
master_ratings['time_code'].values[master_ratings['time_code'].values == 3] = 1

# %%
master_ratings.sample(10)
# Out:
#         ID                                           Location   Longitude  \
# 75  112393  WASHINGTON BLVD & BURLINGTON AVE, LOS ANGELES, CA -118.283285
# 50  187456          ROSCOE BLVD & WILLIS AVE, LOS ANGELES, CA -118.455355
# 61   95186         SHERMAN WAY & WOODMAN AVE, LOS ANGELES, CA -118.431272
# 33  201062  MARTIN LUTHER KING JR BLVD & HALLDALE AVE, LOS... -118.302695
# 71  220910             VERMONT AVE & 65TH ST, LOS ANGELES, CA -118.291800
# 11  138406           CRENSHAW BLVD & 63RD ST, LOS ANGELES, CA -118.330955
# 0   211128        ALVARADO ST & BEVERLY BLVD, LOS ANGELES, CA -118.270324
# 74   54862      VISTA DEL MAR & IMPERIAL HWY, LOS ANGELES, CA -118.436607
# 31  198214  LA TUNA CANYON RD & RT 210 E/B OFF, LOS ANGELE... -118.291577
# 24   84835        IMPERIAL HWY & CENTRAL AVE, LOS ANGELES, CA -118.255274
#
#      Latitude                          geometry  35 mph  Percent Service_S  \
# 75  34.039452   POINT (-118.2832846 34.0394516)       1                0.0
# 50  34.221466   POINT (-118.455355 34.22146606)       1                0.0
# 61  34.201176  POINT (-118.4312723 34.20117569)       1                0.0
# 33  34.010834  POINT (-118.3026949 34.01083374)       1                0.0
# 71  33.980431   POINT (-118.2917999 33.9804306)       1                0.0
# 11  33.982216  POINT (-118.3309552 33.98221588)       1                0.0
# 0   34.066662  POINT (-118.2703238 34.06666183)       1                0.0
# 74  33.934052  POINT (-118.4366075 33.93405151)       0                1.0
# 31  34.234171  POINT (-118.2915769 34.23417126)       0                0.0
# 24  33.929466  POINT (-118.2552735 33.92946625)       1                0.0
#
#     Percent Residential_B  time_code  lights_count
# 75                    1.0          1             2
# 50                    1.0          1             6
# 61                    1.0          1             5
# 33                    1.0          1             3
# 71                    1.0          1             2
# 11                    1.0          1             1
# 0                     1.0          0             5
# 74                    0.0          1             1
# 31                    NaN          0             2
# 24                    1.0          0             2

# %%
#replace all service roads at 50% or more with a 1 for our rating system
master_ratings['lights_count'].values[master_ratings['lights_count'].values < 2.63] = 0

# %%
#replace all service roads at 50% or more with a 1 for our rating system
master_ratings['lights_count'].values[master_ratings['lights_count'].values >= 2.63] = 1

# %%
master_ratings.sample(10)
# Out:
#         ID                                        Location   Longitude  \
# 69  184135       VANOWEN ST & VANTAGE AVE, LOS ANGELES, CA -118.397622
# 30    3363  LA TUNA CANYON RD & ELBEN AVE, LOS ANGELES, CA -118.331053
# 79  179031    WILSHIRE BLVD & FAIRFAX AVE, LOS ANGELES, CA -118.362514
# 54   97881       SATICOY ST & DE SOTO AVE, LOS ANGELES, CA -118.588492
# 77  206521          WESTERN AVE & 79TH ST, LOS ANGELES, CA -118.309022
# 55   55551         SEASIDE AVE & NAVY WAY, LOS ANGELES, CA -118.251812
# 80  136194     WINNETKA AVE & HATTERAS ST, LOS ANGELES, CA -118.571422
# 34  212489        NORDHOFF ST & NOBLE AVE, LOS ANGELES, CA -118.461052
# 1   163711         AVALON BLVD & 118TH PL, LOS ANGELES, CA -118.265210
# 36  220670       NORMANDIE AVE & 255TH ST, LOS ANGELES, CA -118.297502
#
#      Latitude                          geometry  35 mph  Percent Service_S  \
# 69  34.193943  POINT (-118.3976222 34.19394302)       1                1.0
# 30  34.236198  POINT (-118.3310534 34.23619843)       0                1.0
# 79  34.063030  POINT (-118.3625135 34.06303024)       1                0.0
# 54  34.208294  POINT (-118.5884923 34.20829391)       1                0.0
# 77  33.967258  POINT (-118.3090221 33.96725845)       1                0.0
# 55  33.754025  POINT (-118.2518121 33.75402451)       0                1.0
# 80  34.176991  POINT (-118.5714218 34.17699051)       1                0.0
# 34  34.235474  POINT (-118.4610523 34.23547363)       1                0.0
# 1   33.925480  POINT (-118.2652105 33.92547989)       1                0.0
# 36  33.792805  POINT (-118.2975022 33.79280472)       1                0.0
#
#     Percent Residential_B  time_code  lights_count
# 69                    1.0          0             1
# 30                    1.0          1             0
# 79                    1.0          0             0
# 54                    1.0          0             1
# 77                    1.0          0             0
# 55                    0.0          1             0
# 80                    1.0          1             0
# 34                    1.0          0             1
# 1                     1.0          1             0
# 36                    1.0          1             1

# %%
master_ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 82 entries, 0 to 81
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     82 non-null     int64
#  1   Location               82 non-null     object
#  2   Longitude              82 non-null     float64
#  3   Latitude               82 non-null     float64
#  4   geometry               82 non-null     object
#  5   35 mph                 82 non-null     int64
#  6   Percent Service_S      82 non-null     float64
#  7   Percent Residential_B  81 non-null     float64
#  8   time_code              82 non-null     int64
#  9   lights_count           82 non-null     int64
# dtypes: float64(4), int64(4), object(2)
# memory usage: 6.5+ KB

# %%
## master_ratings['Percent Service_S'] = master_ratings['Percent Service_S'].astype(int)

# %%
master_ratings['Total'] = master_ratings['35 mph']+master_ratings['Percent Service_S']+master_ratings['Percent Residential_B']+master_ratings['time_code']++master_ratings['lights_count']
# Out:
# /tmp/ipykernel_54/2555020392.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   master_ratings['Total'] = master_ratings['35 mph']+master_ratings['Percent Service_S']+master_ratings['Percent Residential_B']+master_ratings['time_code']++master_ratings['lights_count']

# %%
master_ratings
# Out:
#         ID                                           Location   Longitude  \
# 0   211128        ALVARADO ST & BEVERLY BLVD, LOS ANGELES, CA -118.270324
# 1   163711            AVALON BLVD & 118TH PL, LOS ANGELES, CA -118.265210
# 2    30937         BEVERLY BLVD & HUDSON AVE, LOS ANGELES, CA -118.333482
# 3   218461             CENTRAL AVE & 29TH ST, LOS ANGELES, CA -118.256083
# 4   216930             CENTRAL AVE & 91ST ST, LOS ANGELES, CA -118.256519
# 5   205044             CENTRAL AVE & 92ND ST, LOS ANGELES, CA -118.256532
# 6   210379          CENTURY BLVD & HOOVER ST, LOS ANGELES, CA -118.286620
# 7   184324            CENTURY BLVD & MAIN ST, LOS ANGELES, CA -118.274077
# 8   221122      CENTURY BLVD & ST ANDREWS PL, LOS ANGELES, CA -118.311170
# 9   188248    CESAR E CHAVEZ AVE & VIGNES ST, LOS ANGELES, CA -118.231832
# 10   33367     CHAUTAUQUA BLVD & ALMOLOYA DR, LOS ANGELES, CA -118.519452
# 11  138406           CRENSHAW BLVD & 63RD ST, LOS ANGELES, CA -118.330955
# 12  173875   CRENSHAW BLVD & WASHINGTON BLVD, LOS ANGELES, CA -118.331083
# 13  175909         CULVER BLVD & SLAUSON AVE, LOS ANGELES, CA -118.414779
# 14  168757            FIGUEROA ST & 108TH ST, LOS ANGELES, CA -118.282622
# 15   58061             FIGUEROA ST & 54TH ST, LOS ANGELES, CA -118.282714
# 16   84065        FIGUEROA ST & PASADENA AVE, LOS ANGELES, CA -118.211342
# 17   14631        FLORENCE AVE & CIMARRON ST, LOS ANGELES, CA -118.315563
# 18  192125        FLORENCE AVE & GRAMERCY PL, LOS ANGELES, CA -118.313738
# 19  143855          FLORENCE AVE & HOOVER ST, LOS ANGELES, CA -118.286905
# 20  185896        FOOTHILL BLVD & VALMONT ST, LOS ANGELES, CA -118.294611
# 21  148431             FULTON AVE & ERWIN ST, LOS ANGELES, CA -118.422526
# 22  195502     GLENOAKS BLVD & WHEATLAND AVE, LOS ANGELES, CA -118.360936
# 23  166954     HAYVENHURST AVE & SHERMAN WAY, LOS ANGELES, CA -118.492420
# 24   84835        IMPERIAL HWY & CENTRAL AVE, LOS ANGELES, CA -118.255274
# 25   84467        IMPERIAL HWY & SUCCESS AVE, LOS ANGELES, CA -118.249615
# 26  184104        IMPERIAL HWY & VERMONT AVE, LOS ANGELES, CA -118.291552
# 27  165861      JEFFERSON BLVD & COCHRAN AVE, LOS ANGELES, CA -118.362546
# 28   85193       LA BREA AVE & DOCKWEILER ST, LOS ANGELES, CA -118.344244
# 29  166529            LA BREA AVE & RODEO RD, LOS ANGELES, CA -118.355626
# 30    3363     LA TUNA CANYON RD & ELBEN AVE, LOS ANGELES, CA -118.331053
# 31  198214  LA TUNA CANYON RD & RT 210 E/B OFF, LOS ANGELE... -118.291577
# 32  218215    LANKERSHIM BLVD & KITTRIDGE ST, LOS ANGELES, CA -118.387802
# 33  201062  MARTIN LUTHER KING JR BLVD & HALLDALE AVE, LOS... -118.302695
# 34  212489           NORDHOFF ST & NOBLE AVE, LOS ANGELES, CA -118.461052
# 35  140850          NORDHOFF ST & TOBIAS AVE, LOS ANGELES, CA -118.451636
# 36  220670          NORMANDIE AVE & 255TH ST, LOS ANGELES, CA -118.297502
# 37   22496           OLYMPIC BLVD & ORME AVE, LOS ANGELES, CA -118.217778
# 38  149918           OSBORNE ST & OSBORNE PL, LOS ANGELES, CA -118.403236
# 39  125922   PACIFIC COAST HWY & FIGUEROA PL, LOS ANGELES, CA -118.284075
# 40  206156     PACIFIC COAST HWY & FRIES AVE, LOS ANGELES, CA -118.265339
# 41  210079      PACIFIC COAST HWY & GULF AVE, LOS ANGELES, CA -118.273985
# 42  210192  PACIFIC COAST HWY & TEMESCAL CANYON RD, LOS AN... -118.535805
# 43   19398         PARTHENIA ST & ENCINO AVE, LOS ANGELES, CA -118.515114
# 44   72094        PARTHENIA ST & HASKELL AVE, LOS ANGELES, CA -118.476392
# 45  121923          PLUMMER ST & HASKELL AVE, LOS ANGELES, CA -118.476282
# 46  210410           POLK ST & GLENOAKS BLVD, LOS ANGELES, CA -118.450074
# 47   97673         ROSCOE BLVD & HASKELL AVE, LOS ANGELES, CA -118.476700
# 48   72067         ROSCOE BLVD & LINDLEY AVE, LOS ANGELES, CA -118.527362
# 49  217687        ROSCOE BLVD & PENFIELD AVE, LOS ANGELES, CA -118.568496
# 50  187456          ROSCOE BLVD & WILLIS AVE, LOS ANGELES, CA -118.455355
# 51  137988    SAN FERNANDO RD & TRUESDALE ST, LOS ANGELES, CA -118.398205
# 52  170646  SAN FERNANDO RD SOUTHWEST RDWY & SIERRA HWY, L... -118.506133
# 53   98193  SANTA MONICA BLVD & LAS PALMAS AVE, LOS ANGELE... -118.336744
# 54   97881          SATICOY ST & DE SOTO AVE, LOS ANGELES, CA -118.588492
# 55   55551            SEASIDE AVE & NAVY WAY, LOS ANGELES, CA -118.251812
# 56  196265     SEPULVEDA BLVD & PARTHENIA ST, LOS ANGELES, CA -118.467662
# 57  184240       SEPULVEDA BLVD & VANOWEN ST, LOS ANGELES, CA -118.466162
# 58  112215  SHERMAN WAY & COLDWATER CANYON AVE, LOS ANGELE... -118.415796
# 59  185828        SHERMAN WAY & ETIWANDA AVE, LOS ANGELES, CA -118.531564
# 60  213515          SHERMAN WAY & IRVINE AVE, LOS ANGELES, CA -118.385592
# 61   95186         SHERMAN WAY & WOODMAN AVE, LOS ANGELES, CA -118.431272
# 62  212505         SLAUSON AVE & FIGUEROA ST, LOS ANGELES, CA -118.282455
# 63  135576          SUNLAND BLVD & NOHLES DR, LOS ANGELES, CA -118.336335
# 64  154627         SUNSET BLVD & FORMOSA AVE, LOS ANGELES, CA -118.346980
# 65  167936         SUNSET BLVD & MALTMAN AVE, LOS ANGELES, CA -118.277098
# 66  168756         SUNSET BLVD & MAPLETON DR, LOS ANGELES, CA -118.431923
# 67   92181    VAN NUYS BLVD & CANTERBURY AVE, LOS ANGELES, CA -118.445139
# 68  173009         VANOWEN ST & BELLAIRE AVE, LOS ANGELES, CA -118.409908
# 69  184135          VANOWEN ST & VANTAGE AVE, LOS ANGELES, CA -118.397622
# 70  142011      VENICE BLVD & ROBERTSON BLVD, LOS ANGELES, CA -118.390382
# 71  220910             VERMONT AVE & 65TH ST, LOS ANGELES, CA -118.291800
# 72  155925           VERNON AVE & CROCKER ST, LOS ANGELES, CA -118.268732
# 73  212959         VINELAND AVE & VANOWEN ST, LOS ANGELES, CA -118.370332
# 74   54862      VISTA DEL MAR & IMPERIAL HWY, LOS ANGELES, CA -118.436607
# 75  112393  WASHINGTON BLVD & BURLINGTON AVE, LOS ANGELES, CA -118.283285
# 76  180452             WESTERN AVE & 78TH ST, LOS ANGELES, CA -118.309022
# 77  206521             WESTERN AVE & 79TH ST, LOS ANGELES, CA -118.309022
# 78  108953             WESTERN AVE & 80TH ST, LOS ANGELES, CA -118.309024
# 79  179031       WILSHIRE BLVD & FAIRFAX AVE, LOS ANGELES, CA -118.362514
# 80  136194        WINNETKA AVE & HATTERAS ST, LOS ANGELES, CA -118.571422
# 81  154179            WOODLEY AVE & RAYEN ST, LOS ANGELES, CA -118.485111
#
#      Latitude                          geometry  35 mph  Percent Service_S  \
# 0   34.066662  POINT (-118.2703238 34.06666183)       1                0.0
# 1   33.925480  POINT (-118.2652105 33.92547989)       1                0.0
# 2   34.076157  POINT (-118.3334822 34.07615662)       1                0.0
# 28                    1.0          1             0    3.0
# 29                    1.0          1             0    4.0
# 30                    1.0          1             0    3.0
# 31                    NaN          0             0    NaN
# 32                    1.0          0             1    3.0
# 33                    1.0          1             1    4.0
# 34                    1.0          0             1    3.0
# 35                    1.0          0             1    4.0
# 36                    1.0          1             1    4.0
# 37                    0.0          1             1    4.0
# 38                    1.0          1             0    3.0
# 39                    1.0          1             0    3.0
# 40                    1.0          0             0    2.0
# 41                    1.0          1             0    3.0
# 42                    1.0          1             0    2.0
# 43                    1.0          0             0    1.0
# 44                    1.0          0             1    3.0
# 45                    1.0          1             1    4.0
# 46                    1.0          1             0    3.0
# 47                    1.0          0             0    2.0
# 48                    1.0          0             1    3.0
# 49                    1.0          1             0    3.0
# 50                    1.0          1             1    4.0
# 51                    0.0          1             0    2.0
# 52                    0.0          1             0    1.0
# 53                    0.0          0             1    3.0
# 54                    1.0          0             1    3.0
# 55                    0.0          1             0    2.0
# 56                    0.0          0             1    3.0
# 57                    1.0          0             1    3.0
# 58                    1.0          0             1    4.0
# 59                    1.0          0             1    3.0
# 60                    1.0          1             0    4.0
# 61                    1.0          1             1    4.0
# 62                    1.0          0             1    3.0
# 63                    1.0          1             0    2.0
# 64                    1.0          1             1    4.0
# 65                    1.0          1             1    4.0
# 66                    1.0          1             0    3.0
# 67                    1.0          1             0    4.0
# 68                    1.0          0             0    2.0
# 69                    1.0          0             1    4.0
# 70                    0.0          1             1    2.0
# 71                    1.0          1             0    3.0
# 72                    1.0          0             0    2.0
# 73                    1.0          0             1    4.0
# 74                    0.0          1             0    2.0
# 75                    1.0          1             0    3.0
# 76                    1.0          1             1    4.0
# 77                    1.0          0             0    2.0
# 78                    1.0          1             1    4.0
# 79                    1.0          0             0    2.0
# 80                    1.0          1             0    3.0
# 81                    1.0          1             0    3.0

# %%
#convert to geodataframe
master_ratings_gdf = gpd.GeoDataFrame(master_ratings, 
                       crs='epsg:4326',
                       geometry=gpd.points_from_xy(master_ratings.Longitude, master_ratings.Latitude))

# %%
#convert to web mercator 
master_ratings_gdf = master_ratings_gdf.to_crs(epsg=3857)

# %%
# map street lights
fig, ax = plt.subplots(figsize=(25,25))

master_ratings_gdf.plot(ax=ax,
        column='Total',
         legend=True,
         scheme='equal_interval')
#set buckets to 1, 2,3 4, 5

# no axis
ax.axis('off')

# add a basemap
ctx.add_basemap(ax,source=ctx.providers.CartoDB.Positron)

# %%
fig = px.scatter_mapbox(master_ratings_gdf,
                        lat='Latitude',
                        lon='Longitude',
                        mapbox_style="carto-positron",
                        color= 'Total',
                        zoom=9, 
                        hover_data=["Location", 
                                    "time_code", 
                                    "35 mph", 
                                    "Percent Service_S", 
                                    "Percent Residential_B", 
                                    "lights_count"],
                        range_color=[1,4],
                        color_continuous_scale='inferno_r'
                       )
fig.show()

# %%
fig.write_html("Rated_locations_interactive.html")

# %%
##Next steps: 
##1. interavtive map where you hover and it shows you details of which characteristics each location has. (Danielle)
##2. chart of totals column
##3. stacked bar chart of interactive (from class week 10) (Danielle) 
## maybe a way to show which combos of characteristics are most commmon
